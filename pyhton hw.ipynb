# %%
#Q1

# %%
name = "sai shayan"
age = 18
height = 6.0
print(name,age,height)
# Out:
# sai shayan 18 6.0

# %%
#Q2

# %%
score = 50
score = 75
print(score)
# Out:
# 75

# %%
#Q3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
#Q4

# %%
x = 5
y = 10
x = y
y = x/2
print(x)
print(y)
# Out:
# 10
# 5.0

# %%
#Q5

# %% [markdown]
# 2total,class are invalid variable names

# %%
#Q6

# %%
price = 19.89
print(type(price))
# Out:
# <class 'float'>

# %%
#Q7

# %% [markdown]
# 1. integer
# 2. string
# 3. float
# 4. bool

# %%
#Q8

# %%
items = [1, "apple", 3.5, True]

for item in items:
    print(type(item))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
#Q9

# %%
a = "42"
print(type(a))
# Out:
# <class 'str'>

# %%
a = 42
print(type(a))
# Out:
# <class 'int'>

# %%
#Q10

# %%
n = 7
if(type(n)==int):
    print('yes')
else:
    print("no")
# Out:
# yes

# %%
#Q11

# %%
 # this represents tax rate
tax_rate = 0.18

# %%
#Q12

# %%
radius = 5 # radius is in 5cm

# %%
#Q13

# %%
html_code = """<div class="hero">
    <p>It's a beautiful day!</p>
</div> it can store mutiple lines of code this is what exactly script dose it store python code in multilines"""

# %%
#Q14

# %%
totl = 10+ # this is a invalid syntax
totl = 10 # this is correct
# Out:
#   Cell In[27], line 1
#     totl = 10+ # this is a invalid syntax
#                ^
# SyntaxError: invalid syntax

# %%
#Q15

# %%
user_name=input("enter your name:")
# Out:
# enter your name: sai

# %%
#Q16

# %%
user_age=int(input("emter your age"))
# Out:
# emter your age 18

# %%
#Q17

# %%
a = float(input('enter you number'))
b = float(input('enter your number'))
c = a+b
print("your total is ",c)
# Out:
# enter you number 3.56
# enter your number 6.78
# your total is  10.34

# %%
#Q18

# %%
a = input("enter a name 1 = ")
b = input("enter a name 2 = ")
c = input("enter a name 3 = ")
# Out:
# enter a name 1 =  sai
# enter a name 2 =  shayan
# enter a name 3 =  rimuru

# %%
#Q19

# %%
a = int(input("enter your number"))
if(a%2==0):
    print('even')
else:
    print('odd')
# Out:
# enter your number 3
# odd

# %%
#Q20

# %%
city = input('enter your city name')
temp = float(input('enter your temperature'))
print("It is",temp,'degrees in',city)
# Out:
# enter your city name hyderabad
# enter your temperature 34.67
# It is 34.67 degrees in hyderabad
